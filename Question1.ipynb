# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("Balaji Fast Food Sales.csv")

# %%
df
# Out:
#      order_id        date        item_name  item_type  item_price  quantity  \
# 0           1  07-03-2022         Aalopuri   Fastfood          20        13
# 1           2   8/23/2022          Vadapav   Fastfood          20        15
# 2           3  11/20/2022          Vadapav   Fastfood          20         1
# 3           4  02-03-2023  Sugarcane juice  Beverages          25         6
# 4           5  10-02-2022  Sugarcane juice  Beverages          25         8
# ..        ...         ...              ...        ...         ...       ...
# 995       996   3/19/2023          Frankie   Fastfood          50        10
# 996       997   9/20/2022         Sandwich   Fastfood          60         7
# 997       998   1/26/2023         Sandwich   Fastfood          60        13
# 998       999   8/27/2022         Panipuri   Fastfood          20         5
# 999      1000   5/29/2022         Aalopuri   Fastfood          20         3
#
# ...

# %%
df.isnull().sum()
# Out:
# order_id                0
# date                    0
# item_name               0
# item_type               0
# item_price              0
# quantity                0
# transaction_amount      0
# transaction_type      107
# received_by             0
# time_of_sale            0
# dtype: int64

# %%
df.head()
# Out:
#    order_id        date        item_name  item_type  item_price  quantity  \
# 0         1  07-03-2022         Aalopuri   Fastfood          20        13
# 1         2   8/23/2022          Vadapav   Fastfood          20        15
# 2         3  11/20/2022          Vadapav   Fastfood          20         1
# 3         4  02-03-2023  Sugarcane juice  Beverages          25         6
# 4         5  10-02-2022  Sugarcane juice  Beverages          25         8
#
#    transaction_amount transaction_type received_by time_of_sale
# 0                 260              NaN         Mr.        Night
# 1                 300             Cash         Mr.    Afternoon
# 2                  20             Cash         Mr.    Afternoon
# 3                 150           Online         Mr.        Night
# 4                 200           Online         Mr.      Evening

# %%
df.tail()
# Out:
#      order_id       date item_name item_type  item_price  quantity  \
# 995       996  3/19/2023   Frankie  Fastfood          50        10
# 996       997  9/20/2022  Sandwich  Fastfood          60         7
# 997       998  1/26/2023  Sandwich  Fastfood          60        13
# 998       999  8/27/2022  Panipuri  Fastfood          20         5
# 999      1000  5/29/2022  Aalopuri  Fastfood          20         3
#
#      transaction_amount transaction_type received_by time_of_sale
# 995                 500              NaN        Mrs.      Evening
# 996                 420              NaN         Mr.      Evening
# 997                 780              NaN         Mr.      Evening
# 998                 100              NaN        Mrs.    Afternoon
# 999                  60           Online        Mrs.     Midnight

# %%
df.columns
# Out:
# Index(['order_id', 'date', 'item_name', 'item_type', 'item_price', 'quantity',
#        'transaction_amount', 'transaction_type', 'received_by',
#        'time_of_sale'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 10)

# %%
type[df]
# Out:
# type[     order_id        date        item_name  item_type  item_price  quantity  \
# 0           1  07-03-2022         Aalopuri   Fastfood          20        13
# 1           2   8/23/2022          Vadapav   Fastfood          20        15
# 2           3  11/20/2022          Vadapav   Fastfood          20         1
# 3           4  02-03-2023  Sugarcane juice  Beverages          25         6
# 4           5  10-02-2022  Sugarcane juice  Beverages          25         8
# ..        ...         ...              ...        ...         ...       ...
# 995       996   3/19/2023          Frankie   Fastfood          50        10
# 996       997   9/20/2022         Sandwich   Fastfood          60         7
# 997       998   1/26/2023         Sandwich   Fastfood          60        13
# 998       999   8/27/2022         Panipuri   Fastfood          20         5
# 999      1000   5/29/2022         Aalopuri   Fastfood          20         3
#
# ...

# %%
df.loc[0]
# Out:
# order_id                       1
# date                  07-03-2022
# item_name               Aalopuri
# item_type               Fastfood
# item_price                    20
# quantity                      13
# transaction_amount           260
# transaction_type             NaN
# received_by                  Mr.
# time_of_sale               Night
# Name: 0, dtype: object

# %%
x=df.iloc[:,:-1]

# %%
y=df.iloc[:,:3]

# %%
x
# Out:
#      order_id        date        item_name  item_type  item_price  quantity  \
# 0           1  07-03-2022         Aalopuri   Fastfood          20        13
# 1           2   8/23/2022          Vadapav   Fastfood          20        15
# 2           3  11/20/2022          Vadapav   Fastfood          20         1
# 3           4  02-03-2023  Sugarcane juice  Beverages          25         6
# 4           5  10-02-2022  Sugarcane juice  Beverages          25         8
# ..        ...         ...              ...        ...         ...       ...
# 995       996   3/19/2023          Frankie   Fastfood          50        10
# 996       997   9/20/2022         Sandwich   Fastfood          60         7
# 997       998   1/26/2023         Sandwich   Fastfood          60        13
# 998       999   8/27/2022         Panipuri   Fastfood          20         5
# 999      1000   5/29/2022         Aalopuri   Fastfood          20         3
#
#      transaction_amount transaction_type received_by
# ...

# %%
y
# Out:
#      order_id        date        item_name
# 0           1  07-03-2022         Aalopuri
# 1           2   8/23/2022          Vadapav
# 2           3  11/20/2022          Vadapav
# 3           4  02-03-2023  Sugarcane juice
# 4           5  10-02-2022  Sugarcane juice
# ..        ...         ...              ...
# 995       996   3/19/2023          Frankie
# 996       997   9/20/2022         Sandwich
# 997       998   1/26/2023         Sandwich
# 998       999   8/27/2022         Panipuri
# 999      1000   5/29/2022         Aalopuri
#
# [1000 rows x 3 columns]
